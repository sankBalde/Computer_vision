# %% [markdown]
# EPITA MLRF practice_04-00_intro v2024-06-10_101414 by Joseph CHAZALON
#
# <div style="overflow: auto; padding: 10px; margin: 10px 0px">
# <img alt="Creative Commons License" src='img/CC-BY-4.0.png' style='float: left; margin-right: 20px'>
#
# This work is licensed under a [Creative Commons Attribution 4.0 International License](http://creativecommons.org/licenses/by/4.0/).
# </div>

# %% [markdown]
# # Practice session 04: Introduction
#
# This session shows how to implement a simple content based image search engine.
#
# ## Goals
# - implement a bag of visual word description:
# - reuse some external ground truth;
# - evaluate the performance of a ranked retrieval system;
# - deliver some search results for grading.
#
#
# ## Agenda
# This session contains a single part: [Bag of Visual Words](practice_04-01_BoVW.ipynb).
#
#
# ## Warning: you are being graded!
# This session is graded. You will need to upload the results you produce on [Moodle](https://moodle.cri.epita.fr/).
#
#
#
# ## Copyright note
# The INRIA Holidays dataset material is copyrighted by INRIA.
#
#
# ## What you need to do
# Make sure you read and understand everything, and complete all the required actions.
# **Required actions** are preceded by the following sign:
# ![Back to work!](img/work.png)

# %% [markdown]
# # Let's get started!
# Now you're ready to move on to the next stage: [Bag of Visual Words](practice_04-01_BoVW.ipynb).
